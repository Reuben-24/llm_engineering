# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants
MODEL = 'gpt-5-nano'

openai = OpenAI()

# %%
# set up environment
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

# %%
# here is the question; type over this to ask something new

question = """
    What's my name?
"""

# %%
# Set up prompts
system_prompt = """
    You receive a technical question and respond with a clear, concise explanation in Markdown.
    If the user's prompt is not a technical question, respond clearly that you can not answer.
    Your response must always be in markdown without code blocks.
"""

def get_user_prompt(user_input):
    user_prompt = f"""
        Here is a technical question, please provide a solution clearly and concisely: 
        {user_input}
    """
    return user_prompt

# %%
# Get gpt-4o-mini to answer, with streaming
def stream_answer(user_input):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages = [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_user_prompt(user_input)}
        ],
        stream=True
    )
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ""
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_answer(question)
# Out:
# I can’t know your name. I don’t have access to personal data unless you share it in this chat. If you tell me your name, I’ll use it. If you’d like help with a different technical question or with choosing a display name, I can help with that too.
